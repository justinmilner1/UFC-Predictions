# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../data/InferencingData/infdata.csv')

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_rows', 200)

# %%
df.T
# Out:
#                                        0                 1     \
# R_fighter                     Derek Brunson  Gregor Gillespie
# B_fighter                     Kevin Holland      Brad Riddell
# Referee                           Herb Dean         Herb Dean
# date                                 20-Mar            21-Mar
# location                               2021              2021
# Winner                                 Draw              Draw
# title_bout                            False             False
# weight_class                   Middleweight       Lightweight
# B_avg_KD                            0.15625              0.25
# B_avg_opp_KD                            0.0               0.0
# B_avg_SIG_STR_pct                  0.791582            0.4775
# B_avg_opp_SIG_STR_pct              0.850586            0.4825
# B_avg_TD_pct                       0.269199              0.58
# B_avg_opp_TD_pct                   0.393398             0.395
# B_avg_SUB_ATT                      0.029297               0.0
# B_avg_opp_SUB_ATT                  0.080078              0.75
# B_avg_REV                          0.023438              0.25
# B_avg_opp_REV                      0.041016              0.75
# B_avg_SIG_STR_att                 39.210938            139.25
# B_avg_SIG_STR_landed              26.078125             65.75
# B_avg_opp_SIG_STR_att             24.494141             91.25
# B_avg_opp_SIG_STR_landed          11.953125              43.0
# B_avg_TOTAL_STR_att               61.644531             158.5
# B_avg_TOTAL_STR_landed            47.791016              84.0
# B_avg_opp_TOTAL_STR_att           31.279297             105.5
# B_avg_opp_TOTAL_STR_landed        17.464844             54.25
# B_avg_TD_att                       0.935547               3.5
# B_avg_TD_landed                    0.529297               1.0
# B_avg_opp_TD_att                   2.759766              11.0
# B_avg_opp_TD_landed                1.451172              4.25
# B_avg_HEAD_att                    31.019531             115.5
# B_avg_HEAD_landed                 19.921875             46.25
# B_avg_opp_HEAD_att                15.763672              72.0
# B_avg_opp_HEAD_landed              5.615234             26.25
# B_avg_BODY_att                     4.162109             16.25
# B_avg_BODY_landed                  2.685547              13.0
# B_avg_opp_BODY_att                 4.707031              9.75
# B_avg_opp_BODY_landed              2.820312              7.75
# B_avg_LEG_att                      4.029297               7.5
# B_avg_LEG_landed                   3.470703               6.5
# B_avg_opp_LEG_att                  4.023438               9.5
# B_avg_opp_LEG_landed               3.517578               9.0
# B_avg_DISTANCE_att                25.355469             120.5
# B_avg_DISTANCE_landed              14.09375             51.25
# B_avg_opp_DISTANCE_att            17.171875              82.5
# B_avg_opp_DISTANCE_landed          7.177734             36.25
# B_avg_CLINCH_att                   3.630859               5.0
# B_avg_CLINCH_landed                2.984375               4.0
# B_avg_opp_CLINCH_att               1.857422               5.5
# B_avg_opp_CLINCH_landed            1.353516               4.0
# B_avg_GROUND_att                  10.224609             13.75
# B_avg_GROUND_landed                     9.0              10.5
# B_avg_opp_GROUND_att               5.464844              3.25
# B_avg_opp_GROUND_landed            3.421875              2.75
# B_avg_CTRL_time(seconds)               69.5            117.25
# B_avg_opp_CTRL_time(seconds)      82.316406             315.0
# B_total_time_fought(seconds)     267.517578             900.0
# B_total_rounds_fought                    23                 9
# B_total_title_bouts                       0                 0
# B_current_win_streak                      0                 3
# B_current_lose_streak                     1                 0
# B_longest_win_streak                      5                 3
# B_wins                                    8                 3
# B_losses                                  2                 0
# B_draw                                    0                 0
# B_win_by_Decision_Majority              0.0               0.0
# B_win_by_Decision_Split                 2.0               1.0
# B_win_by_Decision_Unanimous             1.0               2.0
# B_win_by_KO/TKO                         3.0               0.0
# B_win_by_Submission                     2.0               0.0
# B_win_by_TKO_Doctor_Stoppage            0.0               0.0
# B_Stance                           Orthodox          Orthodox
# B_Height_cms                          190.5            170.18
# B_Reach_cms                          205.74            180.34
# B_Weight_lbs                          185.0             155.0
# R_avg_KD                           0.024551          0.046875
# R_avg_opp_KD                       0.220703               0.5
# R_avg_SIG_STR_pct                  0.515636          0.401406
# R_avg_opp_SIG_STR_pct              0.445974              0.29
# R_avg_TD_pct                       0.355824          0.287187
# R_avg_opp_TD_pct                        0.0               0.0
# R_avg_SUB_ATT                      0.000092           0.28125
# R_avg_opp_SUB_ATT                       0.0               0.0
# R_avg_REV                               0.0              0.25
# R_avg_opp_REV                           0.0              0.25
# R_avg_SIG_STR_att                133.473511          50.78125
# R_avg_SIG_STR_landed              72.179901         22.390625
# R_avg_opp_SIG_STR_att              95.71843         39.328125
# R_avg_opp_SIG_STR_landed          41.511475         13.484375
# R_avg_TOTAL_STR_att              150.523987         61.859375
# R_avg_TOTAL_STR_landed            88.716995          32.03125
# R_avg_opp_TOTAL_STR_att          102.146439          43.65625
# R_avg_opp_TOTAL_STR_landed        47.689285         17.578125
# R_avg_TD_att                       8.111679          4.984375
# R_avg_TD_landed                    3.008209          2.640625
# R_avg_opp_TD_att                    2.15686               0.0
# R_avg_opp_TD_landed                     0.0               0.0
# R_avg_HEAD_att                    98.620758           46.3125
# R_avg_HEAD_landed                  46.65184           18.0625
# R_avg_opp_HEAD_att                66.271027          36.53125
# R_avg_opp_HEAD_landed             20.732513         12.046875
# R_avg_BODY_att                    22.163742          2.859375
# R_avg_BODY_landed                 15.460419           2.71875
# R_avg_opp_BODY_att                21.706512          2.609375
# R_avg_opp_BODY_landed             16.698364              1.25
# R_avg_LEG_att                     12.689011          1.609375
# R_avg_LEG_landed                  10.067642          1.609375
# R_avg_opp_LEG_att                  7.740891            0.1875
# R_avg_opp_LEG_landed               4.080597            0.1875
# R_avg_DISTANCE_att               102.852951          30.71875
# R_avg_DISTANCE_landed              50.01178          6.484375
# R_avg_opp_DISTANCE_att            84.986694         36.203125
# R_avg_opp_DISTANCE_landed         32.964813         11.859375
# R_avg_CLINCH_att                  11.848206          3.203125
# R_avg_CLINCH_landed                7.164001          1.890625
# R_avg_opp_CLINCH_att              10.287552          2.296875
# R_avg_opp_CLINCH_landed            8.202209          1.078125
# R_avg_GROUND_att                  18.772354         16.859375
# R_avg_GROUND_landed                15.00412         14.015625
# R_avg_opp_GROUND_att               0.444183          0.828125
# R_avg_opp_GROUND_landed            0.344452          0.546875
# R_avg_CTRL_time(seconds)         157.812119        226.078125
# R_avg_opp_CTRL_time(seconds)       3.515289          2.296875
# R_total_time_fought(seconds)     683.118561        347.234375
# R_total_rounds_fought                    31                12
# R_total_title_bouts                       0                 0
# R_current_win_streak                      2                 6
# R_current_lose_streak                     0                 0
# R_longest_win_streak                      5                 6
# R_wins                                   12                 6
# R_losses                                  5                 1
# R_draw                                    0                 0
# R_win_by_Decision_Majority              0.0               0.0
# R_win_by_Decision_Split                 0.0               0.0
# R_win_by_Decision_Unanimous             4.0               1.0
# R_win_by_KO/TKO                         7.0               3.0
# R_win_by_Submission                     1.0               2.0
# R_win_by_TKO_Doctor_Stoppage            0.0               0.0
# R_Stance                           Southpaw          Orthodox
# R_Height_cms                         185.42            170.18
# R_Reach_cms                          195.58            180.34
# R_Weight_lbs                          185.0             155.0
# datestring                      20-Mar-2021       21-Mar-2021
# datetime                         2021-03-20        2021-03-21
# B_age                                  28.0              29.0
# R_age                                  37.0              34.0
#
#                                          2              3             4     \
# R_fighter                       Cheyanne Buys   Adrian Yanez    Kenan Song
# B_fighter                     Montserrat Ruiz  Gustavo Lopez   Max Griffin
# Referee                             Herb Dean      Herb Dean     Herb Dean
# date                                   22-Mar         23-Mar        24-Mar
# location                                 2021           2021          2021
# Winner                                   Draw           Draw          Draw
# title_bout                              False          False         False
# weight_class                      CatchWeight   Bantamweight  Welterweight
# B_avg_KD                                  NaN            0.0      0.046875
# B_avg_opp_KD                              NaN            0.0         0.125
# B_avg_SIG_STR_pct                         NaN           0.42      0.459277
# B_avg_opp_SIG_STR_pct                     NaN          0.495      0.404687
# B_avg_TD_pct                              NaN           0.33      0.322188
# B_avg_opp_TD_pct                          NaN           0.36      0.068867
# B_avg_SUB_ATT                             NaN            0.5      0.189453
# B_avg_opp_SUB_ATT                         NaN            1.0           0.0
# B_avg_REV                                 NaN            0.0      0.283203
# B_avg_opp_REV                             NaN            0.0           0.0
# B_avg_SIG_STR_att                         NaN           50.0    130.818359
# B_avg_SIG_STR_landed                      NaN           20.0     60.113281
# B_avg_opp_SIG_STR_att                     NaN           84.0    129.337891
# B_avg_opp_SIG_STR_landed                  NaN           45.0     50.548828
# B_avg_TOTAL_STR_att                       NaN           76.5    151.554688
# B_avg_TOTAL_STR_landed                    NaN           41.0     78.324219
# B_avg_opp_TOTAL_STR_att                   NaN          114.0    137.427734
# B_avg_opp_TOTAL_STR_landed                NaN           64.0     58.507812
# B_avg_TD_att                              NaN            1.5      2.730469
# B_avg_TD_landed                           NaN            1.0      1.453125
# B_avg_opp_TD_att                          NaN            9.0      1.552734
# B_avg_opp_TD_landed                       NaN            6.5      0.285156
# B_avg_HEAD_att                            NaN           39.5    102.328125
# B_avg_HEAD_landed                         NaN           11.0     38.814453
# B_avg_opp_HEAD_att                        NaN           63.0    111.267578
# B_avg_opp_HEAD_landed                     NaN           27.5     37.830078
# B_avg_BODY_att                            NaN            7.5     20.951172
# B_avg_BODY_landed                         NaN            7.0     14.419922
# B_avg_opp_BODY_att                        NaN           12.0      12.15625
# B_avg_opp_BODY_landed                     NaN            9.0      7.179688
# B_avg_LEG_att                             NaN            3.0      7.539062
# B_avg_LEG_landed                          NaN            2.0      6.878906
# B_avg_opp_LEG_att                         NaN            9.0      5.914062
# B_avg_opp_LEG_landed                      NaN            8.5      5.539062
# B_avg_DISTANCE_att                        NaN           35.0    125.130859
# B_avg_DISTANCE_landed                     NaN           12.5     55.888672
# B_avg_opp_DISTANCE_att                    NaN           43.5    122.193359
# B_avg_opp_DISTANCE_landed                 NaN           17.5     45.869141
# B_avg_CLINCH_att                          NaN           10.5       5.03125
# B_avg_CLINCH_landed                       NaN            4.5      3.763672
# B_avg_opp_CLINCH_att                      NaN            4.0      6.263672
# B_avg_opp_CLINCH_landed                   NaN            3.0      3.966797
# B_avg_GROUND_att                          NaN            4.5       0.65625
# B_avg_GROUND_landed                       NaN            3.0      0.460938
# B_avg_opp_GROUND_att                      NaN           36.5      0.880859
# B_avg_opp_GROUND_landed                   NaN           24.5      0.712891
# B_avg_CTRL_time(seconds)                  NaN           34.0    148.507812
# B_avg_opp_CTRL_time(seconds)              NaN          277.5     80.097656
# B_total_time_fought(seconds)              NaN          531.5     809.53125
# B_total_rounds_fought                       0              4            28
# B_total_title_bouts                         0              0             0
# B_current_win_streak                        0              0             0
# B_current_lose_streak                       0              1             1
# B_longest_win_streak                        0              1             1
# B_wins                                      0              1             4
# B_losses                                    0              1             6
# B_draw                                      0              0             0
# B_win_by_Decision_Majority                0.0            0.0           1.0
# B_win_by_Decision_Split                   0.0            0.0           0.0
# B_win_by_Decision_Unanimous               0.0            0.0           1.0
# B_win_by_KO/TKO                           0.0            0.0           2.0
# B_win_by_Submission                       0.0            1.0           0.0
# B_win_by_TKO_Doctor_Stoppage              0.0            0.0           0.0
# B_Stance                                  NaN       Orthodox      Orthodox
# B_Height_cms                              NaN          165.1        180.34
# B_Reach_cms                               NaN         170.18        193.04
# B_Weight_lbs                              NaN          135.0         170.0
# R_avg_KD                                  NaN            1.0           NaN
# R_avg_opp_KD                              NaN            0.0           NaN
# R_avg_SIG_STR_pct                         NaN            0.5           NaN
# R_avg_opp_SIG_STR_pct                     NaN           0.46           NaN
# R_avg_TD_pct                              NaN            0.0           NaN
# R_avg_opp_TD_pct                          NaN            0.0           NaN
# R_avg_SUB_ATT                             NaN            0.0           NaN
# R_avg_opp_SUB_ATT                         NaN            0.0           NaN
# R_avg_REV                                 NaN            0.0           NaN
# R_avg_opp_REV                             NaN            0.0           NaN
# R_avg_SIG_STR_att                         NaN           34.0           NaN
# R_avg_SIG_STR_landed                      NaN           17.0           NaN
# R_avg_opp_SIG_STR_att                     NaN           13.0           NaN
# R_avg_opp_SIG_STR_landed                  NaN            6.0           NaN
# R_avg_TOTAL_STR_att                       NaN           35.0           NaN
# R_avg_TOTAL_STR_landed                    NaN           18.0           NaN
# R_avg_opp_TOTAL_STR_att                   NaN           16.0           NaN
# R_avg_opp_TOTAL_STR_landed                NaN            9.0           NaN
# R_avg_TD_att                              NaN            0.0           NaN
# R_avg_TD_landed                           NaN            0.0           NaN
# R_avg_opp_TD_att                          NaN            3.0           NaN
# R_avg_opp_TD_landed                       NaN            0.0           NaN
# R_avg_HEAD_att                            NaN           32.0           NaN
# R_avg_HEAD_landed                         NaN           15.0           NaN
# R_avg_opp_HEAD_att                        NaN           11.0           NaN
# R_avg_opp_HEAD_landed                     NaN            5.0           NaN
# R_avg_BODY_att                            NaN            2.0           NaN
# R_avg_BODY_landed                         NaN            2.0           NaN
# R_avg_opp_BODY_att                        NaN            2.0           NaN
# R_avg_opp_BODY_landed                     NaN            1.0           NaN
# R_avg_LEG_att                             NaN            0.0           NaN
# R_avg_LEG_landed                          NaN            0.0           NaN
# R_avg_opp_LEG_att                         NaN            0.0           NaN
# R_avg_opp_LEG_landed                      NaN            0.0           NaN
# R_avg_DISTANCE_att                        NaN           33.0           NaN
# R_avg_DISTANCE_landed                     NaN           16.0           NaN
# R_avg_opp_DISTANCE_att                    NaN           12.0           NaN
# R_avg_opp_DISTANCE_landed                 NaN            6.0           NaN
# R_avg_CLINCH_att                          NaN            1.0           NaN
# R_avg_CLINCH_landed                       NaN            1.0           NaN
# R_avg_opp_CLINCH_att                      NaN            1.0           NaN
# R_avg_opp_CLINCH_landed                   NaN            0.0           NaN
# R_avg_GROUND_att                          NaN            0.0           NaN
# R_avg_GROUND_landed                       NaN            0.0           NaN
# R_avg_opp_GROUND_att                      NaN            0.0           NaN
# R_avg_opp_GROUND_landed                   NaN            0.0           NaN
# R_avg_CTRL_time(seconds)                  NaN            5.0           NaN
# R_avg_opp_CTRL_time(seconds)              NaN           54.0           NaN
# R_total_time_fought(seconds)              NaN          166.0           NaN
# R_total_rounds_fought                       0              1             0
# R_total_title_bouts                         0              0             0
# R_current_win_streak                        0              1             0
# R_current_lose_streak                       0              0             0
# R_longest_win_streak                        0              1             0
# R_wins                                      0              1             0
# R_losses                                    0              0             0
# R_draw                                      0              0             0
# R_win_by_Decision_Majority                0.0            0.0           0.0
# R_win_by_Decision_Split                   0.0            0.0           0.0
# R_win_by_Decision_Unanimous               0.0            0.0           0.0
# R_win_by_KO/TKO                           0.0            1.0           0.0
# R_win_by_Submission                       0.0            0.0           0.0
# R_win_by_TKO_Doctor_Stoppage              0.0            0.0           0.0
# R_Stance                               Switch       Orthodox           NaN
# R_Height_cms                           160.02         170.18           NaN
# R_Reach_cms                            160.02          177.8           NaN
# R_Weight_lbs                            115.0          135.0           NaN
# datestring                        22-Mar-2021    23-Mar-2021   24-Mar-2021
# datetime                           2021-03-22     2021-03-23    2021-03-24
# B_age                                     NaN           31.0          35.0
# R_age                                    25.0           27.0           NaN
#
#                                          5              6                7     \
# R_fighter                         Tai Tuivasa  Marion Reneau  Leonardo Santos
# B_fighter                     Harry Hunsucker  Macy Chiasson     Grant Dawson
# Referee                             Herb Dean      Herb Dean        Herb Dean
# date                                   25-Mar         26-Mar           27-Mar
# location                                 2021           2021             2021
# Winner                                   Draw           Draw             Draw
# title_bout                              False          False            False
# weight_class                      Heavyweight   Bantamweight      Lightweight
# B_avg_KD                                  NaN          0.125              0.0
# B_avg_opp_KD                              NaN            0.0              0.0
# B_avg_SIG_STR_pct                         NaN       0.535625            0.515
# B_avg_opp_SIG_STR_pct                     NaN        0.57875          0.47375
# B_avg_TD_pct                              NaN          0.185            0.435
# B_avg_opp_TD_pct                          NaN        0.16625             0.25
# B_avg_SUB_ATT                             NaN          0.125             1.25
# B_avg_opp_SUB_ATT                         NaN         0.1875            0.625
# B_avg_REV                                 NaN           0.25              0.0
# B_avg_opp_REV                             NaN            0.0             0.25
# B_avg_SIG_STR_att                         NaN       109.1875             86.0
# B_avg_SIG_STR_landed                      NaN        57.9375            40.75
# B_avg_opp_SIG_STR_att                     NaN         50.625             55.5
# B_avg_opp_SIG_STR_landed                  NaN        28.4375           25.125
# B_avg_TOTAL_STR_att                       NaN       170.4375          150.625
# B_avg_TOTAL_STR_landed                    NaN        105.625             93.5
# B_avg_opp_TOTAL_STR_att                   NaN         74.375             79.0
# B_avg_opp_TOTAL_STR_landed                NaN          44.25            46.75
# B_avg_TD_att                              NaN          5.375            6.375
# B_avg_TD_landed                           NaN            1.5            2.625
# B_avg_opp_TD_att                          NaN            2.0             0.25
# B_avg_opp_TD_landed                       NaN          0.625             0.25
# B_avg_HEAD_att                            NaN         77.375           60.625
# B_avg_HEAD_landed                         NaN         31.375           23.125
# B_avg_opp_HEAD_att                        NaN        41.5625           42.375
# B_avg_opp_HEAD_landed                     NaN         22.625           14.625
# B_avg_BODY_att                            NaN        31.1875             10.0
# B_avg_BODY_landed                         NaN        26.1875              4.5
# B_avg_opp_BODY_att                        NaN         7.6875           10.625
# B_avg_opp_BODY_landed                     NaN         4.9375             8.25
# B_avg_LEG_att                             NaN          0.625           15.375
# B_avg_LEG_landed                          NaN          0.375           13.125
# B_avg_opp_LEG_att                         NaN          1.375              2.5
# B_avg_opp_LEG_landed                      NaN          0.875             2.25
# B_avg_DISTANCE_att                        NaN        33.5625           68.875
# B_avg_DISTANCE_landed                     NaN           11.0           29.625
# B_avg_opp_DISTANCE_att                    NaN        32.0625           50.125
# B_avg_opp_DISTANCE_landed                 NaN        13.9375            20.25
# B_avg_CLINCH_att                          NaN        39.0625            3.125
# B_avg_CLINCH_landed                       NaN        28.8125              2.0
# B_avg_opp_CLINCH_att                      NaN        13.3125              3.0
# B_avg_opp_CLINCH_landed                   NaN          10.75             2.75
# B_avg_GROUND_att                          NaN        36.5625             14.0
# B_avg_GROUND_landed                       NaN         18.125            9.125
# B_avg_opp_GROUND_att                      NaN           5.25            2.375
# B_avg_opp_GROUND_landed                   NaN           3.75            2.125
# B_avg_CTRL_time(seconds)                  NaN         390.25           431.75
# B_avg_opp_CTRL_time(seconds)              NaN       156.3125           17.375
# B_total_time_fought(seconds)              NaN          764.0          717.875
# B_total_rounds_fought                       0             11               10
# B_total_title_bouts                         0              1                0
# B_current_win_streak                        0              3                4
# B_current_lose_streak                       0              0                0
# B_longest_win_streak                        0              3                4
# B_wins                                      0              4                4
# B_losses                                    0              1                0
# B_draw                                      0              0                0
# B_win_by_Decision_Majority                0.0            0.0              0.0
# B_win_by_Decision_Split                   0.0            0.0              0.0
# B_win_by_Decision_Unanimous               0.0            1.0              2.0
# B_win_by_KO/TKO                           0.0            2.0              0.0
# B_win_by_Submission                       0.0            1.0              2.0
# B_win_by_TKO_Doctor_Stoppage              0.0            0.0              0.0
# B_Stance                             Orthodox       Orthodox           Switch
# B_Height_cms                           187.96         180.34            177.8
# B_Reach_cms                             190.5         182.88           182.88
# B_Weight_lbs                            241.0          135.0            145.0
# R_avg_KD                             0.546875            0.0           0.3125
# R_avg_opp_KD                           0.1875       0.000977         0.015625
# R_avg_SIG_STR_pct                    0.538906       0.403076         0.565156
# R_avg_opp_SIG_STR_pct                0.598594       0.554961         0.343594
# R_avg_TD_pct                              0.0       0.511719         0.337031
# R_avg_opp_TD_pct                       0.3125        0.62875         0.048906
# R_avg_SUB_ATT                             0.0       0.231445         0.039062
# R_avg_opp_SUB_ATT                        0.25        0.03125              0.0
# R_avg_REV                                 0.0        0.03125              0.0
# R_avg_opp_REV                             0.0            0.5              0.5
# R_avg_SIG_STR_att                   59.234375     109.331055        78.929688
# R_avg_SIG_STR_landed                   30.375      44.362305          42.1875
# R_avg_opp_SIG_STR_att                 43.8125      148.84668        78.617188
# R_avg_opp_SIG_STR_landed            24.796875      84.554688        32.046875
# R_avg_TOTAL_STR_att                      70.5     137.154297       110.914062
# R_avg_TOTAL_STR_landed              41.390625      70.198242          68.0625
# R_avg_opp_TOTAL_STR_att             50.234375     172.499023        99.289062
# R_avg_opp_TOTAL_STR_landed           30.90625     106.680664        48.898438
# R_avg_TD_att                          0.03125       2.261719          1.40625
# R_avg_TD_landed                           0.0       1.261719         0.632812
# R_avg_opp_TD_att                      2.84375       3.137695           5.6875
# R_avg_opp_TD_landed                      1.75       1.771484         0.515625
# R_avg_HEAD_att                           42.5         86.375        65.195312
# R_avg_HEAD_landed                    16.78125      26.030273         32.28125
# R_avg_opp_HEAD_att                  34.296875      94.225586        54.765625
# R_avg_opp_HEAD_landed                 17.9375      38.693359        14.320312
# R_avg_BODY_att                        5.78125      17.272461         9.609375
# R_avg_BODY_landed                    4.546875      13.469727         5.945312
# R_avg_opp_BODY_att                      6.125      37.717773        16.726562
# R_avg_opp_BODY_landed                 3.71875      31.658203        11.304688
# R_avg_LEG_att                       10.953125       5.683594            4.125
# R_avg_LEG_landed                     9.046875       4.862305         3.960938
# R_avg_opp_LEG_att                    3.390625       16.90332            7.125
# R_avg_opp_LEG_landed                 3.140625      14.203125         6.421875
# R_avg_DISTANCE_att                     45.875      85.845703         62.28125
# R_avg_DISTANCE_landed                20.28125      27.907227        28.882812
# R_avg_opp_DISTANCE_att               36.34375     106.913086        67.539062
# R_avg_opp_DISTANCE_landed             18.6875      48.479492         25.15625
# R_avg_CLINCH_att                    11.328125      18.996094         6.234375
# R_avg_CLINCH_landed                    8.5625      13.970703         5.171875
# R_avg_opp_CLINCH_att                   1.4375        35.3125            3.875
# R_avg_opp_CLINCH_landed              1.171875       32.05957         3.273438
# R_avg_GROUND_att                      2.03125       4.489258        10.414062
# R_avg_GROUND_landed                   1.53125       2.484375         8.132812
# R_avg_opp_GROUND_att                  6.03125       6.621094         7.203125
# R_avg_opp_GROUND_landed                4.9375       4.015625         3.617188
# R_avg_CTRL_time(seconds)            82.453125     141.285156         59.03125
# R_avg_opp_CTRL_time(seconds)         89.78125     310.152344       193.546875
# R_total_time_fought(seconds)       448.203125     874.380859       649.304688
# R_total_rounds_fought                      13             30               18
# R_total_title_bouts                         0              0                1
# R_current_win_streak                        3              2                1
# R_current_lose_streak                       0              0                0
# R_longest_win_streak                        3              2                6
# R_wins                                      4              5                7
# R_losses                                    3              6                1
# R_draw                                      0              0                0
# R_win_by_Decision_Majority                0.0            0.0              0.0
# R_win_by_Decision_Split                   0.0            0.0              1.0
# R_win_by_Decision_Unanimous               1.0            1.0              2.0
# R_win_by_KO/TKO                           3.0            2.0              2.0
# R_win_by_Submission                       0.0            2.0              2.0
# R_win_by_TKO_Doctor_Stoppage              0.0            0.0              0.0
# R_Stance                             Southpaw       Orthodox         Orthodox
# R_Height_cms                           187.96         167.64           182.88
# R_Reach_cms                             190.5         172.72            190.5
# R_Weight_lbs                            264.0          135.0            155.0
# datestring                        25-Mar-2021    26-Mar-2021      27-Mar-2021
# datetime                           2021-03-25     2021-03-26       2021-03-27
# B_age                                    32.0           29.0             27.0
# R_age                                    28.0           43.0             41.0
#
#                                        8               9     ...  \
# R_fighter                      Trevin Giles  Montel Jackson  ...
# B_fighter                     Roman Dolidze   Jesse Strader  ...
# Referee                           Herb Dean       Herb Dean  ...
# date                                 28-Mar          29-Mar  ...
# location                               2021            2021  ...
# Winner                                 Draw            Draw  ...
# title_bout                            False           False  ...
# weight_class                   Middleweight    Bantamweight  ...
# B_avg_KD                                0.5             NaN  ...
# B_avg_opp_KD                            0.0             NaN  ...
# B_avg_SIG_STR_pct                      0.66             NaN  ...
# B_avg_opp_SIG_STR_pct                 0.305             NaN  ...
# B_avg_TD_pct                            0.3             NaN  ...
# B_avg_opp_TD_pct                        0.5             NaN  ...
# B_avg_SUB_ATT                           1.5             NaN  ...
# B_avg_opp_SUB_ATT                       0.0             NaN  ...
# B_avg_REV                               0.0             NaN  ...
# B_avg_opp_REV                           0.0             NaN  ...
# B_avg_SIG_STR_att                      65.5             NaN  ...
# B_avg_SIG_STR_landed                   35.0             NaN  ...
# B_avg_opp_SIG_STR_att                  50.0             NaN  ...
# B_avg_opp_SIG_STR_landed               16.5             NaN  ...
# B_avg_TOTAL_STR_att                   113.5             NaN  ...
# B_avg_TOTAL_STR_landed                 68.5             NaN  ...
# B_avg_opp_TOTAL_STR_att                68.5             NaN  ...
# B_avg_opp_TOTAL_STR_landed             29.0             NaN  ...
# B_avg_TD_att                            2.5             NaN  ...
# B_avg_TD_landed                         1.5             NaN  ...
# B_avg_opp_TD_att                        0.5             NaN  ...
# B_avg_opp_TD_landed                     0.5             NaN  ...
# B_avg_HEAD_att                         46.0             NaN  ...
# B_avg_HEAD_landed                      20.0             NaN  ...
# B_avg_opp_HEAD_att                     36.0             NaN  ...
# B_avg_opp_HEAD_landed                   7.5             NaN  ...
# B_avg_BODY_att                         12.0             NaN  ...
# B_avg_BODY_landed                       8.0             NaN  ...
# B_avg_opp_BODY_att                      8.0             NaN  ...
# B_avg_opp_BODY_landed                   3.0             NaN  ...
# B_avg_LEG_att                           7.5             NaN  ...
# B_avg_LEG_landed                        7.0             NaN  ...
# B_avg_opp_LEG_att                       6.0             NaN  ...
# B_avg_opp_LEG_landed                    6.0             NaN  ...
# B_avg_DISTANCE_att                     58.0             NaN  ...
# B_avg_DISTANCE_landed                  30.0             NaN  ...
# B_avg_opp_DISTANCE_att                 48.0             NaN  ...
# B_avg_opp_DISTANCE_landed              15.5             NaN  ...
# B_avg_CLINCH_att                        0.5             NaN  ...
# B_avg_CLINCH_landed                     0.5             NaN  ...
# B_avg_opp_CLINCH_att                    0.5             NaN  ...
# B_avg_opp_CLINCH_landed                 0.5             NaN  ...
# B_avg_GROUND_att                        7.0             NaN  ...
# B_avg_GROUND_landed                     4.5             NaN  ...
# B_avg_opp_GROUND_att                    1.5             NaN  ...
# B_avg_opp_GROUND_landed                 0.5             NaN  ...
# B_avg_CTRL_time(seconds)              219.5             NaN  ...
# B_avg_opp_CTRL_time(seconds)           24.5             NaN  ...
# B_total_time_fought(seconds)          577.5             NaN  ...
# B_total_rounds_fought                     4               0  ...
# B_total_title_bouts                       0               0  ...
# B_current_win_streak                      2               0  ...
# B_current_lose_streak                     0               0  ...
# B_longest_win_streak                      2               0  ...
# B_wins                                    2               0  ...
# B_losses                                  0               0  ...
# B_draw                                    0               0  ...
# B_win_by_Decision_Majority              0.0             0.0  ...
# B_win_by_Decision_Split                 1.0             0.0  ...
# B_win_by_Decision_Unanimous             0.0             0.0  ...
# B_win_by_KO/TKO                         1.0             0.0  ...
# B_win_by_Submission                     0.0             0.0  ...
# B_win_by_TKO_Doctor_Stoppage            0.0             0.0  ...
# B_Stance                           Orthodox             NaN  ...
# B_Height_cms                         187.96             NaN  ...
# B_Reach_cms                          193.04             NaN  ...
# B_Weight_lbs                          205.0             NaN  ...
# R_avg_KD                            1.03125            0.75  ...
# R_avg_opp_KD                         0.0625             0.0  ...
# R_avg_SIG_STR_pct                  0.576875           0.615  ...
# R_avg_opp_SIG_STR_pct               0.38125        0.474375  ...
# R_avg_TD_pct                        0.40625         0.66875  ...
# R_avg_opp_TD_pct                    0.11625        0.386875  ...
# R_avg_SUB_ATT                          0.25          0.0625  ...
# R_avg_opp_SUB_ATT                    1.1875            1.25  ...
# R_avg_REV                             0.375           0.625  ...
# R_avg_opp_REV                          0.25             0.0  ...
# R_avg_SIG_STR_att                   77.5625            68.0  ...
# R_avg_SIG_STR_landed               43.15625            43.0  ...
# R_avg_opp_SIG_STR_att              69.15625         28.1875  ...
# R_avg_opp_SIG_STR_landed           27.59375         12.9375  ...
# R_avg_TOTAL_STR_att                  93.125         117.625  ...
# R_avg_TOTAL_STR_landed             57.21875         88.4375  ...
# R_avg_opp_TOTAL_STR_att            98.34375         41.6875  ...
# R_avg_opp_TOTAL_STR_landed         52.46875           25.25  ...
# R_avg_TD_att                        1.28125           5.875  ...
# R_avg_TD_landed                     0.78125            4.25  ...
# R_avg_opp_TD_att                     4.6875         12.9375  ...
# R_avg_opp_TD_landed                  0.4375          4.8125  ...
# R_avg_HEAD_att                     71.09375         55.4375  ...
# R_avg_HEAD_landed                   38.0625         31.8125  ...
# R_avg_opp_HEAD_att                 50.40625            17.5  ...
# R_avg_opp_HEAD_landed              13.34375          5.1875  ...
# R_avg_BODY_att                       4.6875             9.0  ...
# R_avg_BODY_landed                    3.3125          8.3125  ...
# R_avg_opp_BODY_att                  9.09375          5.6875  ...
# R_avg_opp_BODY_landed               6.15625             3.5  ...
# R_avg_LEG_att                       1.78125          3.5625  ...
# R_avg_LEG_landed                    1.78125           2.875  ...
# R_avg_opp_LEG_att                   9.65625             5.0  ...
# R_avg_opp_LEG_landed                8.09375            4.25  ...
# R_avg_DISTANCE_att                  58.3125          41.875  ...
# R_avg_DISTANCE_landed               30.4375          21.625  ...
# R_avg_opp_DISTANCE_att              63.3125          21.875  ...
# R_avg_opp_DISTANCE_landed            23.125            8.25  ...
# R_avg_CLINCH_att                    6.96875            19.5  ...
# R_avg_CLINCH_landed                 3.65625         15.6875  ...
# R_avg_opp_CLINCH_att                    5.0            5.25  ...
# R_avg_opp_CLINCH_landed               4.125          4.1875  ...
# R_avg_GROUND_att                   12.28125           6.625  ...
# R_avg_GROUND_landed                  9.0625          5.6875  ...
# R_avg_opp_GROUND_att                0.84375          1.0625  ...
# R_avg_opp_GROUND_landed             0.34375             0.5  ...
# R_avg_CTRL_time(seconds)          176.15625        301.5625  ...
# R_avg_opp_CTRL_time(seconds)       154.6875           303.5  ...
# R_total_time_fought(seconds)      747.34375           850.0  ...
# R_total_rounds_fought                    17              13  ...
# R_total_title_bouts                       0               0  ...
# R_current_win_streak                      2               0  ...
# R_current_lose_streak                     0               1  ...
# R_longest_win_streak                      2               3  ...
# R_wins                                    4               3  ...
# R_losses                                  2               2  ...
# R_draw                                    0               0  ...
# R_win_by_Decision_Majority              0.0             0.0  ...
# R_win_by_Decision_Split                 1.0             0.0  ...
# R_win_by_Decision_Unanimous             0.0             2.0  ...
# R_win_by_KO/TKO                         3.0             0.0  ...
# R_win_by_Submission                     0.0             1.0  ...
# R_win_by_TKO_Doctor_Stoppage            0.0             0.0  ...
# R_Stance                           Orthodox        Southpaw  ...
# R_Height_cms                         182.88           177.8  ...
# R_Reach_cms                          187.96           190.5  ...
# R_Weight_lbs                          185.0           135.0  ...
# datestring                      28-Mar-2021     29-Mar-2021  ...
# datetime                         2021-03-28      2021-03-29  ...
# B_age                                  32.0             NaN  ...
# R_age                                  28.0            28.0  ...
#
#                                        5966           5967             5968  \
# R_fighter                     Johnny Rhodes  Patrick Smith     Royce Gracie
# B_fighter                       Fred Ettish   Scott Morris  Minoki Ichihara
# Referee                       John McCarthy  John McCarthy    John McCarthy
# date                                 11-Mar         11-Mar           11-Mar
# location                               1994           1994             1994
# Winner                                  Red            Red              Red
# title_bout                            False          False            False
# weight_class                     OpenWeight     OpenWeight       OpenWeight
# B_avg_KD                                NaN            0.0              NaN
# B_avg_opp_KD                            NaN            0.0              NaN
# B_avg_SIG_STR_pct                       NaN            1.0              NaN
# B_avg_opp_SIG_STR_pct                   NaN            0.0              NaN
# B_avg_TD_pct                            NaN            1.0              NaN
# B_avg_opp_TD_pct                        NaN            0.0              NaN
# B_avg_SUB_ATT                           NaN            1.0              NaN
# B_avg_opp_SUB_ATT                       NaN            0.0              NaN
# B_avg_REV                               NaN            0.0              NaN
# B_avg_opp_REV                           NaN            0.0              NaN
# B_avg_SIG_STR_att                       NaN            1.0              NaN
# B_avg_SIG_STR_landed                    NaN            1.0              NaN
# B_avg_opp_SIG_STR_att                   NaN            4.0              NaN
# B_avg_opp_SIG_STR_landed                NaN            0.0              NaN
# B_avg_TOTAL_STR_att                     NaN            2.0              NaN
# B_avg_TOTAL_STR_landed                  NaN            2.0              NaN
# B_avg_opp_TOTAL_STR_att                 NaN            5.0              NaN
# B_avg_opp_TOTAL_STR_landed              NaN            1.0              NaN
# B_avg_TD_att                            NaN            1.0              NaN
# B_avg_TD_landed                         NaN            1.0              NaN
# B_avg_opp_TD_att                        NaN            0.0              NaN
# B_avg_opp_TD_landed                     NaN            0.0              NaN
# B_avg_HEAD_att                          NaN            1.0              NaN
# B_avg_HEAD_landed                       NaN            1.0              NaN
# B_avg_opp_HEAD_att                      NaN            2.0              NaN
# B_avg_opp_HEAD_landed                   NaN            0.0              NaN
# B_avg_BODY_att                          NaN            0.0              NaN
# B_avg_BODY_landed                       NaN            0.0              NaN
# B_avg_opp_BODY_att                      NaN            0.0              NaN
# B_avg_opp_BODY_landed                   NaN            0.0              NaN
# B_avg_LEG_att                           NaN            0.0              NaN
# B_avg_LEG_landed                        NaN            0.0              NaN
# B_avg_opp_LEG_att                       NaN            2.0              NaN
# B_avg_opp_LEG_landed                    NaN            0.0              NaN
# B_avg_DISTANCE_att                      NaN            0.0              NaN
# B_avg_DISTANCE_landed                   NaN            0.0              NaN
# B_avg_opp_DISTANCE_att                  NaN            3.0              NaN
# B_avg_opp_DISTANCE_landed               NaN            0.0              NaN
# B_avg_CLINCH_att                        NaN            1.0              NaN
# B_avg_CLINCH_landed                     NaN            1.0              NaN
# B_avg_opp_CLINCH_att                    NaN            1.0              NaN
# B_avg_opp_CLINCH_landed                 NaN            0.0              NaN
# B_avg_GROUND_att                        NaN            0.0              NaN
# B_avg_GROUND_landed                     NaN            0.0              NaN
# B_avg_opp_GROUND_att                    NaN            0.0              NaN
# B_avg_opp_GROUND_landed                 NaN            0.0              NaN
# B_avg_CTRL_time(seconds)                NaN            0.0              NaN
# B_avg_opp_CTRL_time(seconds)            NaN            0.0              NaN
# B_total_time_fought(seconds)            NaN           20.0              NaN
# B_total_rounds_fought                     0              1                0
# B_total_title_bouts                       0              0                0
# B_current_win_streak                      0              1                0
# B_current_lose_streak                     0              0                0
# B_longest_win_streak                      0              1                0
# B_wins                                    0              1                0
# ...
# R_avg_SIG_STR_pct                          NaN              NaN
# R_avg_opp_SIG_STR_pct                      NaN              NaN
# R_avg_TD_pct                               NaN              NaN
# R_avg_opp_TD_pct                           NaN              NaN
# R_avg_SUB_ATT                              NaN              NaN
# R_avg_opp_SUB_ATT                          NaN              NaN
# R_avg_REV                                  NaN              NaN
# R_avg_opp_REV                              NaN              NaN
# R_avg_SIG_STR_att                          NaN              NaN
# R_avg_SIG_STR_landed                       NaN              NaN
# R_avg_opp_SIG_STR_att                      NaN              NaN
# R_avg_opp_SIG_STR_landed                   NaN              NaN
# R_avg_TOTAL_STR_att                        NaN              NaN
# R_avg_TOTAL_STR_landed                     NaN              NaN
# R_avg_opp_TOTAL_STR_att                    NaN              NaN
# R_avg_opp_TOTAL_STR_landed                 NaN              NaN
# R_avg_TD_att                               NaN              NaN
# R_avg_TD_landed                            NaN              NaN
# R_avg_opp_TD_att                           NaN              NaN
# R_avg_opp_TD_landed                        NaN              NaN
# R_avg_HEAD_att                             NaN              NaN
# R_avg_HEAD_landed                          NaN              NaN
# R_avg_opp_HEAD_att                         NaN              NaN
# R_avg_opp_HEAD_landed                      NaN              NaN
# R_avg_BODY_att                             NaN              NaN
# R_avg_BODY_landed                          NaN              NaN
# R_avg_opp_BODY_att                         NaN              NaN
# R_avg_opp_BODY_landed                      NaN              NaN
# R_avg_LEG_att                              NaN              NaN
# R_avg_LEG_landed                           NaN              NaN
# R_avg_opp_LEG_att                          NaN              NaN
# R_avg_opp_LEG_landed                       NaN              NaN
# R_avg_DISTANCE_att                         NaN              NaN
# R_avg_DISTANCE_landed                      NaN              NaN
# R_avg_opp_DISTANCE_att                     NaN              NaN
# R_avg_opp_DISTANCE_landed                  NaN              NaN
# R_avg_CLINCH_att                           NaN              NaN
# R_avg_CLINCH_landed                        NaN              NaN
# R_avg_opp_CLINCH_att                       NaN              NaN
# R_avg_opp_CLINCH_landed                    NaN              NaN
# R_avg_GROUND_att                           NaN              NaN
# R_avg_GROUND_landed                        NaN              NaN
# R_avg_opp_GROUND_att                       NaN              NaN
# R_avg_opp_GROUND_landed                    NaN              NaN
# R_avg_CTRL_time(seconds)                   NaN              NaN
# R_avg_opp_CTRL_time(seconds)               NaN              NaN
# R_total_time_fought(seconds)               NaN              NaN
# R_total_rounds_fought                        0                0
# R_total_title_bouts                          0                0
# R_current_win_streak                         0                0
# R_current_lose_streak                        0                0
# R_longest_win_streak                         0                0
# R_wins                                       0                0
# R_losses                                     0                0
# R_draw                                       0                0
# R_win_by_Decision_Majority                 0.0              0.0
# R_win_by_Decision_Split                    0.0              0.0
# R_win_by_Decision_Unanimous                0.0              0.0
# R_win_by_KO/TKO                            0.0              0.0
# R_win_by_Submission                        0.0              0.0
# R_win_by_TKO_Doctor_Stoppage               0.0              0.0
# R_Stance                              Southpaw              NaN
# R_Height_cms                             177.8              NaN
# R_Reach_cms                                NaN              NaN
# R_Weight_lbs                             170.0              NaN
# datestring                         11-Mar-1994      11-Mar-1994
# datetime                            1994-03-11       1994-03-11
# B_age                                      NaN              NaN
# R_age                                      NaN              NaN
#
#                                        5973           5974            5975
# R_fighter                     Johnny Rhodes  Patrick Smith    Scott Morris
# B_fighter                     David Levicki     Ray Wizard  Sean Daugherty
# Referee                       John McCarthy  John McCarthy   John McCarthy
# date                                 11-Mar         11-Mar          11-Mar
# location                               1994           1994            1994
# Winner                                  Red            Red             Red
# title_bout                            False          False           False
# weight_class                     OpenWeight     OpenWeight      OpenWeight
# B_avg_KD                                NaN            NaN             NaN
# B_avg_opp_KD                            NaN            NaN             NaN
# B_avg_SIG_STR_pct                       NaN            NaN             NaN
# B_avg_opp_SIG_STR_pct                   NaN            NaN             NaN
# B_avg_TD_pct                            NaN            NaN             NaN
# B_avg_opp_TD_pct                        NaN            NaN             NaN
# B_avg_SUB_ATT                           NaN            NaN             NaN
# B_avg_opp_SUB_ATT                       NaN            NaN             NaN
# B_avg_REV                               NaN            NaN             NaN
# B_avg_opp_REV                           NaN            NaN             NaN
# B_avg_SIG_STR_att                       NaN            NaN             NaN
# B_avg_SIG_STR_landed                    NaN            NaN             NaN
# B_avg_opp_SIG_STR_att                   NaN            NaN             NaN
# B_avg_opp_SIG_STR_landed                NaN            NaN             NaN
# B_avg_TOTAL_STR_att                     NaN            NaN             NaN
# B_avg_TOTAL_STR_landed                  NaN            NaN             NaN
# B_avg_opp_TOTAL_STR_att                 NaN            NaN             NaN
# B_avg_opp_TOTAL_STR_landed              NaN            NaN             NaN
# B_avg_TD_att                            NaN            NaN             NaN
# B_avg_TD_landed                         NaN            NaN             NaN
# B_avg_opp_TD_att                        NaN            NaN             NaN
# B_avg_opp_TD_landed                     NaN            NaN             NaN
# B_avg_HEAD_att                          NaN            NaN             NaN
# B_avg_HEAD_landed                       NaN            NaN             NaN
# B_avg_opp_HEAD_att                      NaN            NaN             NaN
# B_avg_opp_HEAD_landed                   NaN            NaN             NaN
# B_avg_BODY_att                          NaN            NaN             NaN
# B_avg_BODY_landed                       NaN            NaN             NaN
# B_avg_opp_BODY_att                      NaN            NaN             NaN
# B_avg_opp_BODY_landed                   NaN            NaN             NaN
# B_avg_LEG_att                           NaN            NaN             NaN
# B_avg_LEG_landed                        NaN            NaN             NaN
# B_avg_opp_LEG_att                       NaN            NaN             NaN
# B_avg_opp_LEG_landed                    NaN            NaN             NaN
# B_avg_DISTANCE_att                      NaN            NaN             NaN
# B_avg_DISTANCE_landed                   NaN            NaN             NaN
# B_avg_opp_DISTANCE_att                  NaN            NaN             NaN
# B_avg_opp_DISTANCE_landed               NaN            NaN             NaN
# B_avg_CLINCH_att                        NaN            NaN             NaN
# B_avg_CLINCH_landed                     NaN            NaN             NaN
# B_avg_opp_CLINCH_att                    NaN            NaN             NaN
# B_avg_opp_CLINCH_landed                 NaN            NaN             NaN
# B_avg_GROUND_att                        NaN            NaN             NaN
# B_avg_GROUND_landed                     NaN            NaN             NaN
# B_avg_opp_GROUND_att                    NaN            NaN             NaN
# B_avg_opp_GROUND_landed                 NaN            NaN             NaN
# B_avg_CTRL_time(seconds)                NaN            NaN             NaN
# B_avg_opp_CTRL_time(seconds)            NaN            NaN             NaN
# B_total_time_fought(seconds)            NaN            NaN             NaN
# B_total_rounds_fought                     0              0               0
# B_total_title_bouts                       0              0               0
# B_current_win_streak                      0              0               0
# B_current_lose_streak                     0              0               0
# B_longest_win_streak                      0              0               0
# B_wins                                    0              0               0
# B_losses                                  0              0               0
# B_draw                                    0              0               0
# B_win_by_Decision_Majority              0.0            0.0             0.0
# B_win_by_Decision_Split                 0.0            0.0             0.0
# B_win_by_Decision_Unanimous             0.0            0.0             0.0
# B_win_by_KO/TKO                         0.0            0.0             0.0
# B_win_by_Submission                     0.0            0.0             0.0
# B_win_by_TKO_Doctor_Stoppage            0.0            0.0             0.0
# B_Stance                                NaN            NaN             NaN
# B_Height_cms                         195.58            NaN          182.88
# B_Reach_cms                             NaN            NaN             NaN
# B_Weight_lbs                          275.0            NaN           175.0
# R_avg_KD                                NaN            NaN             NaN
# R_avg_opp_KD                            NaN            NaN             NaN
# R_avg_SIG_STR_pct                       NaN            NaN             NaN
# R_avg_opp_SIG_STR_pct                   NaN            NaN             NaN
# R_avg_TD_pct                            NaN            NaN             NaN
# R_avg_opp_TD_pct                        NaN            NaN             NaN
# R_avg_SUB_ATT                           NaN            NaN             NaN
# R_avg_opp_SUB_ATT                       NaN            NaN             NaN
# R_avg_REV                               NaN            NaN             NaN
# R_avg_opp_REV                           NaN            NaN             NaN
# R_avg_SIG_STR_att                       NaN            NaN             NaN
# R_avg_SIG_STR_landed                    NaN            NaN             NaN
# R_avg_opp_SIG_STR_att                   NaN            NaN             NaN
# R_avg_opp_SIG_STR_landed                NaN            NaN             NaN
# R_avg_TOTAL_STR_att                     NaN            NaN             NaN
# R_avg_TOTAL_STR_landed                  NaN            NaN             NaN
# R_avg_opp_TOTAL_STR_att                 NaN            NaN             NaN
# R_avg_opp_TOTAL_STR_landed              NaN            NaN             NaN
# R_avg_TD_att                            NaN            NaN             NaN
# R_avg_TD_landed                         NaN            NaN             NaN
# R_avg_opp_TD_att                        NaN            NaN             NaN
# R_avg_opp_TD_landed                     NaN            NaN             NaN
# R_avg_HEAD_att                          NaN            NaN             NaN
# R_avg_HEAD_landed                       NaN            NaN             NaN
# R_avg_opp_HEAD_att                      NaN            NaN             NaN
# R_avg_opp_HEAD_landed                   NaN            NaN             NaN
# R_avg_BODY_att                          NaN            NaN             NaN
# R_avg_BODY_landed                       NaN            NaN             NaN
# R_avg_opp_BODY_att                      NaN            NaN             NaN
# R_avg_opp_BODY_landed                   NaN            NaN             NaN
# R_avg_LEG_att                           NaN            NaN             NaN
# R_avg_LEG_landed                        NaN            NaN             NaN
# R_avg_opp_LEG_att                       NaN            NaN             NaN
# R_avg_opp_LEG_landed                    NaN            NaN             NaN
# R_avg_DISTANCE_att                      NaN            NaN             NaN
# R_avg_DISTANCE_landed                   NaN            NaN             NaN
# R_avg_opp_DISTANCE_att                  NaN            NaN             NaN
# R_avg_opp_DISTANCE_landed               NaN            NaN             NaN
# R_avg_CLINCH_att                        NaN            NaN             NaN
# R_avg_CLINCH_landed                     NaN            NaN             NaN
# R_avg_opp_CLINCH_att                    NaN            NaN             NaN
# R_avg_opp_CLINCH_landed                 NaN            NaN             NaN
# R_avg_GROUND_att                        NaN            NaN             NaN
# R_avg_GROUND_landed                     NaN            NaN             NaN
# R_avg_opp_GROUND_att                    NaN            NaN             NaN
# R_avg_opp_GROUND_landed                 NaN            NaN             NaN
# R_avg_CTRL_time(seconds)                NaN            NaN             NaN
# R_avg_opp_CTRL_time(seconds)            NaN            NaN             NaN
# R_total_time_fought(seconds)            NaN            NaN             NaN
# R_total_rounds_fought                     0              0               0
# R_total_title_bouts                       0              0               0
# R_current_win_streak                      0              0               0
# R_current_lose_streak                     0              0               0
# R_longest_win_streak                      0              0               0
# R_wins                                    0              0               0
# R_losses                                  0              0               0
# R_draw                                    0              0               0
# R_win_by_Decision_Majority              0.0            0.0             0.0
# R_win_by_Decision_Split                 0.0            0.0             0.0
# R_win_by_Decision_Unanimous             0.0            0.0             0.0
# R_win_by_KO/TKO                         0.0            0.0             0.0
# R_win_by_Submission                     0.0            0.0             0.0
# R_win_by_TKO_Doctor_Stoppage            0.0            0.0             0.0
# R_Stance                           Orthodox       Orthodox        Orthodox
# R_Height_cms                         182.88         187.96           177.8
# R_Reach_cms                             NaN            NaN             NaN
# R_Weight_lbs                          210.0          225.0           210.0
# datestring                      11-Mar-1994    11-Mar-1994     11-Mar-1994
# datetime                         1994-03-11     1994-03-11      1994-03-11
# B_age                                   NaN            NaN            18.0
# R_age                                   NaN          -70.0             NaN
#
# [146 rows x 5976 columns]

# %%
df.describe()
# Out:
#           location     B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# count  5976.000000  4557.000000   4557.000000        4557.000000
# mean   2013.335341     0.246995      0.176623           0.452969
# std       5.558122     0.378456      0.324732           0.131016
# min    1994.000000     0.000000      0.000000           0.000000
# 25%    2010.000000     0.000000      0.000000           0.375312
# 50%    2014.000000     0.015625      0.000000           0.450000
# 75%    2018.000000     0.500000      0.250000           0.527500
# max    2021.000000     5.000000      3.000000           1.000000
#
#        B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# count            4557.000000   4557.000000       4557.000000    4557.000000
# mean                0.434473      0.292932          0.269135       0.479877
# std                 0.133262      0.274271          0.267252       0.725802
# min                 0.000000      0.000000          0.000000       0.000000
# 25%                 0.350625      0.030391          0.033047       0.000000
# 50%                 0.428125      0.250000          0.200000       0.148438
# 75%                 0.510000      0.500000          0.423568       0.750000
# max                 1.000000      1.000000          1.000000       8.000000
#
#        B_avg_opp_SUB_ATT    B_avg_REV  ...  R_win_by_Decision_Split  \
# count        4557.000000  4557.000000  ...              5976.000000
# mean            0.410397     0.157430  ...                 0.305388
# std             0.654802     0.343079  ...                 0.617955
# min             0.000000     0.000000  ...                 0.000000
# 25%             0.000000     0.000000  ...                 0.000000
# 50%             0.109375     0.000000  ...                 0.000000
# 75%             0.531250     0.125000  ...                 0.000000
# max             7.000000     4.000000  ...                 5.000000
#
#        R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# count                  5976.000000       5976.00000          5976.000000
# mean                      1.245649          1.29585             0.794679
# std                       1.675688          1.85702             1.355915
# min                       0.000000          0.00000             0.000000
# 25%                       0.000000          0.00000             0.000000
# 50%                       1.000000          1.00000             0.000000
# 75%                       2.000000          2.00000             1.000000
# max                      10.000000         11.00000            13.000000
#
#        R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# count                   5976.000000   5971.000000  5569.000000   5973.000000
# mean                       0.069277    179.012785   183.589230    170.786037
# std                        0.274226      8.807640    10.576551     35.749488
# min                        0.000000    152.400000   152.400000    115.000000
# 25%                        0.000000    172.720000   177.800000    145.000000
# 50%                        0.000000    180.340000   182.880000    170.000000
# 75%                        0.000000    185.420000   190.500000    185.000000
# max                        2.000000    210.820000   213.360000    345.000000
#
#              B_age        R_age
# count  5801.000000  5912.000000
# mean     26.701086    26.687585
# std      15.453332    16.798557
# min     -76.000000   -76.000000
# 25%      26.000000    26.000000
# 50%      29.000000    29.000000
# 75%      32.000000    32.000000
# max      45.000000    44.000000
#
# [8 rows x 135 columns]

# %% [markdown]
# ## Dealing with NaNs

# %%
for column in df.columns:
    if df[column].isnull().sum()!=0:
        print(f"Nan in {column}: {df[column].isnull().sum()}")
# Out:
# Nan in Referee: 31
# Nan in B_avg_KD: 1419
# Nan in B_avg_opp_KD: 1419
# Nan in B_avg_SIG_STR_pct: 1419
# Nan in B_avg_opp_SIG_STR_pct: 1419
# Nan in B_avg_TD_pct: 1419
# Nan in B_avg_opp_TD_pct: 1419
# Nan in B_avg_SUB_ATT: 1419
# Nan in B_avg_opp_SUB_ATT: 1419
# Nan in B_avg_REV: 1419
# Nan in B_avg_opp_REV: 1419
# Nan in B_avg_SIG_STR_att: 1419
# Nan in B_avg_SIG_STR_landed: 1419
# Nan in B_avg_opp_SIG_STR_att: 1419
# Nan in B_avg_opp_SIG_STR_landed: 1419
# Nan in B_avg_TOTAL_STR_att: 1419
# Nan in B_avg_TOTAL_STR_landed: 1419
# Nan in B_avg_opp_TOTAL_STR_att: 1419
# Nan in B_avg_opp_TOTAL_STR_landed: 1419
# Nan in B_avg_TD_att: 1419
# Nan in B_avg_TD_landed: 1419
# Nan in B_avg_opp_TD_att: 1419
# Nan in B_avg_opp_TD_landed: 1419
# Nan in B_avg_HEAD_att: 1419
# Nan in B_avg_HEAD_landed: 1419
# Nan in B_avg_opp_HEAD_att: 1419
# Nan in B_avg_opp_HEAD_landed: 1419
# Nan in B_avg_BODY_att: 1419
# Nan in B_avg_BODY_landed: 1419
# Nan in B_avg_opp_BODY_att: 1419
# Nan in B_avg_opp_BODY_landed: 1419
# Nan in B_avg_LEG_att: 1419
# Nan in B_avg_LEG_landed: 1419
# Nan in B_avg_opp_LEG_att: 1419
# Nan in B_avg_opp_LEG_landed: 1419
# Nan in B_avg_DISTANCE_att: 1419
# Nan in B_avg_DISTANCE_landed: 1419
# Nan in B_avg_opp_DISTANCE_att: 1419
# Nan in B_avg_opp_DISTANCE_landed: 1419
# Nan in B_avg_CLINCH_att: 1419
# Nan in B_avg_CLINCH_landed: 1419
# Nan in B_avg_opp_CLINCH_att: 1419
# Nan in B_avg_opp_CLINCH_landed: 1419
# Nan in B_avg_GROUND_att: 1419
# Nan in B_avg_GROUND_landed: 1419
# Nan in B_avg_opp_GROUND_att: 1419
# Nan in B_avg_opp_GROUND_landed: 1419
# Nan in B_avg_CTRL_time(seconds): 1419
# Nan in B_avg_opp_CTRL_time(seconds): 1419
# Nan in B_total_time_fought(seconds): 1419
# Nan in B_Stance: 70
# Nan in B_Height_cms: 13
# Nan in B_Reach_cms: 895
# Nan in B_Weight_lbs: 10
# Nan in R_avg_KD: 716
# Nan in R_avg_opp_KD: 716
# Nan in R_avg_SIG_STR_pct: 716
# Nan in R_avg_opp_SIG_STR_pct: 716
# Nan in R_avg_TD_pct: 716
# Nan in R_avg_opp_TD_pct: 716
# Nan in R_avg_SUB_ATT: 716
# Nan in R_avg_opp_SUB_ATT: 716
# Nan in R_avg_REV: 716
# Nan in R_avg_opp_REV: 716
# Nan in R_avg_SIG_STR_att: 716
# Nan in R_avg_SIG_STR_landed: 716
# Nan in R_avg_opp_SIG_STR_att: 716
# Nan in R_avg_opp_SIG_STR_landed: 716
# Nan in R_avg_TOTAL_STR_att: 716
# Nan in R_avg_TOTAL_STR_landed: 716
# Nan in R_avg_opp_TOTAL_STR_att: 716
# Nan in R_avg_opp_TOTAL_STR_landed: 716
# Nan in R_avg_TD_att: 716
# Nan in R_avg_TD_landed: 716
# Nan in R_avg_opp_TD_att: 716
# Nan in R_avg_opp_TD_landed: 716
# Nan in R_avg_HEAD_att: 716
# Nan in R_avg_HEAD_landed: 716
# Nan in R_avg_opp_HEAD_att: 716
# Nan in R_avg_opp_HEAD_landed: 716
# Nan in R_avg_BODY_att: 716
# Nan in R_avg_BODY_landed: 716
# Nan in R_avg_opp_BODY_att: 716
# Nan in R_avg_opp_BODY_landed: 716
# Nan in R_avg_LEG_att: 716
# Nan in R_avg_LEG_landed: 716
# Nan in R_avg_opp_LEG_att: 716
# Nan in R_avg_opp_LEG_landed: 716
# Nan in R_avg_DISTANCE_att: 716
# Nan in R_avg_DISTANCE_landed: 716
# Nan in R_avg_opp_DISTANCE_att: 716
# Nan in R_avg_opp_DISTANCE_landed: 716
# Nan in R_avg_CLINCH_att: 716
# Nan in R_avg_CLINCH_landed: 716
# Nan in R_avg_opp_CLINCH_att: 716
# Nan in R_avg_opp_CLINCH_landed: 716
# Nan in R_avg_GROUND_att: 716
# Nan in R_avg_GROUND_landed: 716
# Nan in R_avg_opp_GROUND_att: 716
# Nan in R_avg_opp_GROUND_landed: 716
# Nan in R_avg_CTRL_time(seconds): 716
# Nan in R_avg_opp_CTRL_time(seconds): 716
# Nan in R_total_time_fought(seconds): 716
# Nan in R_Stance: 30
# Nan in R_Height_cms: 5
# Nan in R_Reach_cms: 407
# Nan in R_Weight_lbs: 3
# Nan in B_age: 175
# Nan in R_age: 64

# %% [markdown]
# * Looks like the blue fighter stats have 1387 missing rows and the red fighter stats have 704 missing rows, i.e those fighters must not have had any previous fights. We should replace these values with the median.

# %%
df2 = df.copy()

# %% [markdown]
# * Referee doesn't look like an important column. Let's delete that.
# * Let's see if height and reach have a correlation
# * The rest i.e. Age, Stance and Height, let's fill with the median of that column.

# %%
df2.drop(columns=['Referee'], inplace=True)

# %%
df2['R_Reach_cms']
# Out:
# 0       195.58
# 1       180.34
# 2       160.02
# 3       177.80
# 4          NaN
#          ...
# 5971       NaN
# 5972       NaN
# 5973       NaN
# 5974       NaN
# 5975       NaN
# Name: R_Reach_cms, Length: 5976, dtype: float64

# %%
# Set style of scatterplot
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

# Create scatterplot of dataframe
sns.lmplot('R_Height_cms', # Horizontal axis
           'R_Reach_cms', # Vertical axis
           data=df2, # Data source
           fit_reg=True # fix a regression line
           ) # S marker size
# Out:
# /Users/justinmilner/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# * We can see there is a positive correlation between height and reach. So we'll replace reach with height

# %%
#df2['R_Reach_cms'].fillna(df2['R_Height_cms'], inplace=True)
#df2['B_Reach_cms'].fillna(df2['B_Height_cms'], inplace=True)
df2.fillna(df2.median(), inplace=True)

# %%
df2['B_Stance'].value_counts()
# Out:
# Orthodox       4507
# Southpaw       1152
# Switch          234
# Open Stance       9
# Sideways          4
# Name: B_Stance, dtype: int64

# %%
df2['R_Stance'].value_counts()
# Out:
# Orthodox       4524
# Southpaw       1215
# Switch          190
# Open Stance      15
# Sideways          2
# Name: R_Stance, dtype: int64

# %%
df2['R_Stance'].fillna('Orthodox', inplace=True)
df2['B_Stance'].fillna('Orthodox', inplace=True)

# %%
for column in df2.columns:
    if df2[column].isnull().sum()!=0:
        print(f"Nan in {column}: {df2[column].isnull().sum()}")

# %% [markdown]
# ## Removing non essential columns

# %%
df2['location'].value_counts()
# Out:
# 2019    516
# 2014    503
# 2016    493
# 2018    474
# 2015    473
# 2017    457
# 2020    456
# 2013    386
# 2012    341
# 2011    300
# 2010    253
# 2009    215
# 2008    201
# 2007    171
# 2006    158
# 2005     80
# 2021     80
# 2002     53
# 1999     44
# 2000     43
# 2003     41
# 2001     40
# 1997     39
# 2004     39
# 1996     36
# 1995     34
# 1994     29
# 1998     21
# Name: location, dtype: int64

# %% [markdown]
# * Since we don't have home-country of each fighter, location is useless
# * Date of the fight is also not essential since we already created age with it
# * Draws are incredibly rare and should be removed from the target variable so it becomes a binary classification task
# * Fighter names are also to be removed

# %%
df2['Winner'].value_counts()
# Out:
# Red     3953
# Blue    1903
# Draw     120
# Name: Winner, dtype: int64

# %%
df2.drop(df2.index[df2['Winner'] == 'Draw'], inplace = True)
df2.drop(columns=['location', 'date', 'R_fighter', 'B_fighter'], inplace=True)

# %%
df2.dtypes
# Out:
# Winner                           object
# title_bout                         bool
# weight_class                     object
# B_avg_KD                        float64
# B_avg_opp_KD                    float64
# B_avg_SIG_STR_pct               float64
# B_avg_opp_SIG_STR_pct           float64
# B_avg_TD_pct                    float64
# B_avg_opp_TD_pct                float64
# B_avg_SUB_ATT                   float64
# B_avg_opp_SUB_ATT               float64
# B_avg_REV                       float64
# B_avg_opp_REV                   float64
# B_avg_SIG_STR_att               float64
# B_avg_SIG_STR_landed            float64
# B_avg_opp_SIG_STR_att           float64
# B_avg_opp_SIG_STR_landed        float64
# B_avg_TOTAL_STR_att             float64
# B_avg_TOTAL_STR_landed          float64
# B_avg_opp_TOTAL_STR_att         float64
# B_avg_opp_TOTAL_STR_landed      float64
# B_avg_TD_att                    float64
# B_avg_TD_landed                 float64
# B_avg_opp_TD_att                float64
# B_avg_opp_TD_landed             float64
# B_avg_HEAD_att                  float64
# B_avg_HEAD_landed               float64
# B_avg_opp_HEAD_att              float64
# B_avg_opp_HEAD_landed           float64
# B_avg_BODY_att                  float64
# B_avg_BODY_landed               float64
# B_avg_opp_BODY_att              float64
# B_avg_opp_BODY_landed           float64
# B_avg_LEG_att                   float64
# B_avg_LEG_landed                float64
# B_avg_opp_LEG_att               float64
# B_avg_opp_LEG_landed            float64
# B_avg_DISTANCE_att              float64
# B_avg_DISTANCE_landed           float64
# B_avg_opp_DISTANCE_att          float64
# B_avg_opp_DISTANCE_landed       float64
# B_avg_CLINCH_att                float64
# B_avg_CLINCH_landed             float64
# B_avg_opp_CLINCH_att            float64
# B_avg_opp_CLINCH_landed         float64
# B_avg_GROUND_att                float64
# B_avg_GROUND_landed             float64
# B_avg_opp_GROUND_att            float64
# B_avg_opp_GROUND_landed         float64
# B_avg_CTRL_time(seconds)        float64
# B_avg_opp_CTRL_time(seconds)    float64
# B_total_time_fought(seconds)    float64
# B_total_rounds_fought             int64
# B_total_title_bouts               int64
# B_current_win_streak              int64
# B_current_lose_streak             int64
# B_longest_win_streak              int64
# B_wins                            int64
# B_losses                          int64
# B_draw                            int64
# B_win_by_Decision_Majority        int64
# B_win_by_Decision_Split           int64
# B_win_by_Decision_Unanimous       int64
# B_win_by_KO/TKO                   int64
# B_win_by_Submission               int64
# B_win_by_TKO_Doctor_Stoppage      int64
# B_Stance                         object
# B_Height_cms                    float64
# B_Reach_cms                     float64
# B_Weight_lbs                    float64
# R_avg_KD                        float64
# R_avg_opp_KD                    float64
# R_avg_SIG_STR_pct               float64
# R_avg_opp_SIG_STR_pct           float64
# R_avg_TD_pct                    float64
# R_avg_opp_TD_pct                float64
# R_avg_SUB_ATT                   float64
# R_avg_opp_SUB_ATT               float64
# R_avg_REV                       float64
# R_avg_opp_REV                   float64
# R_avg_SIG_STR_att               float64
# R_avg_SIG_STR_landed            float64
# R_avg_opp_SIG_STR_att           float64
# R_avg_opp_SIG_STR_landed        float64
# R_avg_TOTAL_STR_att             float64
# R_avg_TOTAL_STR_landed          float64
# R_avg_opp_TOTAL_STR_att         float64
# R_avg_opp_TOTAL_STR_landed      float64
# R_avg_TD_att                    float64
# R_avg_TD_landed                 float64
# R_avg_opp_TD_att                float64
# R_avg_opp_TD_landed             float64
# R_avg_HEAD_att                  float64
# R_avg_HEAD_landed               float64
# R_avg_opp_HEAD_att              float64
# R_avg_opp_HEAD_landed           float64
# R_avg_BODY_att                  float64
# R_avg_BODY_landed               float64
# R_avg_opp_BODY_att              float64
# R_avg_opp_BODY_landed           float64
# R_avg_LEG_att                   float64
# R_avg_LEG_landed                float64
# R_avg_opp_LEG_att               float64
# R_avg_opp_LEG_landed            float64
# R_avg_DISTANCE_att              float64
# R_avg_DISTANCE_landed           float64
# R_avg_opp_DISTANCE_att          float64
# R_avg_opp_DISTANCE_landed       float64
# R_avg_CLINCH_att                float64
# R_avg_CLINCH_landed             float64
# R_avg_opp_CLINCH_att            float64
# R_avg_opp_CLINCH_landed         float64
# R_avg_GROUND_att                float64
# R_avg_GROUND_landed             float64
# R_avg_opp_GROUND_att            float64
# R_avg_opp_GROUND_landed         float64
# R_avg_CTRL_time(seconds)        float64
# R_avg_opp_CTRL_time(seconds)    float64
# R_total_time_fought(seconds)    float64
# R_total_rounds_fought             int64
# R_total_title_bouts               int64
# R_current_win_streak              int64
# R_current_lose_streak             int64
# R_longest_win_streak              int64
# R_wins                            int64
# R_losses                          int64
# R_draw                            int64
# R_win_by_Decision_Majority        int64
# R_win_by_Decision_Split           int64
# R_win_by_Decision_Unanimous       int64
# R_win_by_KO/TKO                   int64
# R_win_by_Submission               int64
# R_win_by_TKO_Doctor_Stoppage      int64
# R_Stance                         object
# R_Height_cms                    float64
# R_Reach_cms                     float64
# R_Weight_lbs                    float64
# B_age                           float64
# R_age                           float64
# dtype: object

# %% [markdown]
# * Weight class and Stance are categories, Winner is out target variable.
# * We can one hot encode the categories

# %%
df2 = pd.concat([df2, pd.get_dummies(df2[['weight_class', 'B_Stance', 'R_Stance']])], axis=1)
df2.drop(columns=['weight_class', 'B_Stance', 'R_Stance'], inplace=True)b
# Out:
#   File "<ipython-input-20-37712017d8cc>", line 2
#     df2.drop(columns=['weight_class', 'B_Stance', 'R_Stance'], inplace=True)b
#                                                                             ^
# SyntaxError: invalid syntax

# %%
df2
# Out:
#      Winner  title_bout  weight_class  B_avg_KD  B_avg_opp_KD  \
# 0      Blue       False   Heavyweight  0.046875      0.070312
# 1       Red       False  Bantamweight  0.001991      0.289082
# 2      Blue       False   Lightweight  0.039551      0.008089
# 3       Red       False     Flyweight  0.015137      0.000000
# 4      Blue       False   Lightweight  0.759773      0.019547
# ...     ...         ...           ...       ...           ...
# 5938    Red       False    OpenWeight  0.015137      0.000000
# 5939    Red       False    OpenWeight  0.015137      0.000000
# 5940    Red       False    OpenWeight  0.015137      0.000000
# 5941    Red       False    OpenWeight  0.015137      0.000000
# 5942    Red       False    OpenWeight  0.015137      0.000000
#
#       B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  \
# 0              0.552969               0.412422      0.207031
# 1              0.444719               0.516684      0.141343
# 2              0.375617               0.431954      0.196597
# 3              0.450000               0.428125      0.250000
# 4              0.588316               0.504957      0.248394
# ...                 ...                    ...           ...
# 5938           0.450000               0.428125      0.250000
# 5939           0.450000               0.428125      0.250000
# 5940           0.450000               0.428125      0.250000
# 5941           0.450000               0.428125      0.250000
# 5942           0.450000               0.428125      0.250000
#
#       B_avg_opp_TD_pct  B_avg_SUB_ATT  ...  R_win_by_Decision_Unanimous  \
# 0             0.152188       0.000000  ...                            2
# 1             0.000017       0.016671  ...                            1
# 2             0.330535       0.002093  ...                            6
# 3             0.200000       0.147461  ...                            1
# 4             0.002326       0.750267  ...                            3
# ...                ...            ...  ...                          ...
# 5938          0.200000       0.147461  ...                            0
# 5939          0.200000       0.147461  ...                            0
# 5940          0.200000       0.147461  ...                            0
# 5941          0.200000       0.147461  ...                            0
# 5942          0.200000       0.147461  ...                            0
#
#       R_win_by_KO/TKO  R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  \
# 0                   9                    0                             0
# 1                   3                    1                             0
# 2                   4                    0                             0
# 3                   2                    2                             0
# 4                   3                    2                             0
# ...               ...                  ...                           ...
# 5938                0                    0                             0
# 5939                0                    0                             0
# 5940                0                    0                             0
# 5941                0                    0                             0
# 5942                0                    0                             0
#
#       R_Stance  R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0     Orthodox        193.04       203.20         265.0    NaN    NaN
# 1       Switch        180.34       177.80         135.0    NaN    NaN
# 2     Southpaw        177.80       185.42         155.0    NaN    NaN
# 3     Orthodox        165.10       170.18         125.0    NaN    NaN
# 4     Orthodox        175.26       187.96         155.0    NaN    NaN
# ...        ...           ...          ...           ...    ...    ...
# 5938  Southpaw        177.80       177.80         170.0    NaN    NaN
# 5939  Orthodox        180.34       182.88         170.0    NaN    NaN
# 5940  Orthodox        182.88       182.88         210.0    NaN    NaN
# 5941  Orthodox        187.96       187.96         225.0    NaN    NaN
# 5942  Orthodox        177.80       177.80         210.0    NaN    NaN
#
# [5836 rows x 139 columns]

# %% [markdown]
# ## Saving the data

# %%
df2.to_csv('../data/preprocessed_data_rajeev.csv', index=False)
